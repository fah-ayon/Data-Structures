# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  if root == None:
    return None
  root.left,root.right = root.right,root.left
  convert_mirror(root.left)
  convert_mirror(root.right)
  return root


#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def smallest_level(root,level=0, dict={}):
  if root==None:
    return None
  if level not in dict:
    dict[level]=root.elem
  else:
    if dict[level]>root.elem:
      dict[level]=root.elem
  smallest_level(root.left,level+1,dict)
  smallest_level(root.right,level+1,dict)
  return dict

#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 -5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# Task 3

# %%
def inorder_predecessor(root, x):
  if root == x:
    return inorder_predecessor(root.left,x)
  if root.right == None:
    return root
  return inorder_predecessor(root.right,x)



#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 20: 14

# %% [markdown]
# Task 4

# %%
def BST(root, i):
    if i < root.elem and root.left == None:
        n = BTNode(i)
        root.left = n
    elif i>root.elem and root.right == None:
        n = BTNode(i)
        root.right = n
    if i < root.elem and root.left != None:
        BST(root.left,i)
    elif i > root.elem and root.right != None:
        BST(root.right, i)

# %%
def LCA(root, x, y):
  if root == None:
    return None
  if x < root.elem and y < root.elem:
    return LCA (root.left, x, y)
  elif x > root.elem and y > root.elem:
    return LCA(root.right, x, y)
  else:
    return root.elem

#DRIVER CODE
#Write by yourself from the given tree
arr=[15,10,8,6,9,12,25,20,18,22,30]
root=BTNode(arr[0])
for i in arr[1:]:
  BST(root,i)


print(LCA(root,6,12))
print(LCA(root,20,6))
print(LCA(root,18,22))
print(LCA(root,20,25))
print(LCA(root,10,12))
# Out:
# 10
# 15
# 20
# 25
# 10

# %% [markdown]
# BONUS TASK 1

# %%
#WRITE THE FUNCTION and DRIVER CODE BY YOURSELF

def sum(root,lvl = 0):
    if root == None:
      return 0
    left= sum(root.left,lvl+1)
    right = sum(root.right,lvl+1)
    #print(root.elem,left,right)

    if root.left == None and root.right == None:
      return root.elem + left + right
    elif left+right == root.elem:
      if lvl==0:
        return True
      else:
        return root.elem + left + right
    elif left==False or right== False:
      return False
    else:
      return False




root = BTNode(26)
n2 = BTNode(10)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(6)
n6 = BTNode(3)

root.left = n2
root.right = n3
n2.left = n4
n2.right = n5
n3.right = n6

result = sum(root)
print(result)
# Out:
# True

# %% [markdown]
# Bonus Task 2

# %%
#WRITE THE FUNCTION BY YOURSELF
def sum_nodes(root, lvl = 0):
  left = right = 0
  if root.left != None:
    left = sum_nodes(root.left, lvl+1)
  if root.right != None:
    right = sum_nodes(root.right, lvl+1)

  if lvl%2 == 0 :
    return left + right - root.elem
  else:
    return left + right + root.elem


#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8
print(sum_nodes(root))
# Out:
# 4
